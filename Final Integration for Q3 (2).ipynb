# %%
import pandas as pd

# %%
df1 = pd.read_csv("1000_entertainment_channels_CLEAN.csv")
df1['Category'] = 'Entertainment'
df1.to_csv("1000_entertainment_channels_CLEAN.csv", index=False)
df1.head(50)
# Out:
#                                 Channel_Name                Channel_ID  \
# 0                     All Week Entertainment  UCPELdRVBaHlYAKJpjR0hJZQ
# 1                          ANS Entertainment  UC8mlgT6I0aSexwFPsOgMG_g
# 2                            Entertain Train  UCQkuCY-t01khJBsI5x4vF0Q
# 3                                    REAL TV  UC2LDKJzY2xZu8pynYnY5N4Q
# 4                    Channel 4 Entertainment  UCz1hQ68G3XPVYEBoFDgSjcQ
# 5                     Green TV Entertainment  UCF2ltLX1dnPa6-L1paPaMzw
# 6                           E! Entertainment  UCj7V_ikJOXO9RC8at6kYfHQ
# 7              Music & Entertainment Channel  UCyVlMYT6Mdd07Z3j72xVFpg
# 8                      Real entertainment tv  UCJb5shn4LSDtcZbBlftCzTQ
# 9                  Regal Entertainment, Inc.  UC69I8egELqWywoX5wrh2KxQ
# 10                  Channel i Entertainment   UCO5DuUbUSJNS6A7tgfOLpaA
# 11             Manipur Entertainment Channel  UClu7ojroyfSWwfkNm0wuXtQ
# ...

# %%
df2 = pd.read_csv("1000_educational_channels_CLEAN.csv")
df2['Category'] = 'Educational'
df2.to_csv("1000_educational_channels_CLEAN.csv", index=False)
df2.head(50)
# Out:
#                                          Channel_Name  \
# 0                             ABC Educational Channel
# 1                                Educational Channel
# 2                Meekah - Educational Videos for Kids
# 3                 Kids Tv - Preschool Learning Videos
# 4   Toddler Learning Videos For Kids - Lucas & Fri...
# 5                              The Education channel
# 6                           Myanmar Education Channel
# 7                                   Kids TV Education
# 8                          The Home Education Channel
# 9            Kids Learn and Grow - Educational Videos
# 10                            Guyana Learning Channel
# 11                                 Brain Education TV
# 12                  Smart Kids - Educational & Fun TV
# 13                             SUVI Education Channel
# 14                        Education Channel With Azra
# 15                          Smile and Learn - English
# ...

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['Channel_Name', 'Channel_ID', 'Channel_URL', 'Views_Last_Year',
#        'Likes_Last_Year', 'Comments_Last_Year', 'Videos_Counted', 'Category'],
#       dtype='object')
# Index(['Channel_Name', 'Channel_ID', 'Channel_URL', 'Views_Last_Year',
#        'Likes_Last_Year', 'Comments_Last_Year', 'Videos_Counted', 'Category'],
#       dtype='object')

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
print(df['Category'].value_counts())
# Out:
# Category
# Entertainment    590
# Educational      426
# Name: count, dtype: int64

# %%
df.to_csv("integrated Q3.csv", index=False)
